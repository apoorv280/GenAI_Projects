# %%
# !pip install streamlit
# !npm install localtunnel
# Out:
# ⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹
# added 22 packages in 3s
# ⠹
# ⠹3 packages are looking for funding
# ⠹  run `npm fund` for details
# ⠹

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
save_path = '/content/drive/MyDrive/genAI'

# %%
import tensorflow as tf
import numpy as np
import pandas as pd
from pyngrok import ngrok
import os
import time
from tf_keras.models import load_model
import pickle

# %%
## loading all models

model = load_model(os.path.join(save_path,'model.h5'))

## load encoder and scalar
with open(os.path.join(save_path,'label_encoder_gender.pkl'),'rb') as file:
  label_encoder_gender = pickle.load(file)

with open(os.path.join(save_path,'onehot_encoder_geo.pkl'),'rb') as file:
  onehot_encoder_geo = pickle.load(file)

with open(os.path.join(save_path,'scaler.pkl'),'rb') as file:
  scaler = pickle.load(file)

# %%
# %%writefile app.py

save_path = '/content/drive/MyDrive/genAI'

import streamlit as st
import tensorflow as tf
import numpy as np
import pandas as pd
from pyngrok import ngrok
import os
import time
from tf_keras.models import load_model
import pickle

## loading all models

model = load_model(os.path.join(save_path,'model.h5'))

## load encoder and scalar
with open(os.path.join(save_path,'label_encoder_gender.pkl'),'rb') as file:
  label_encoder_gender = pickle.load(file)

with open(os.path.join(save_path,'onehot_encoder_geo.pkl'),'rb') as file:
  onehot_encoder_geo = pickle.load(file)

with open(os.path.join(save_path,'scaler.pkl'),'rb') as file:
  scaler = pickle.load(file)


## Streamlit app
st.title('Customer Churn Prediction')

## userinput
geography = st.selectbox('Geography', onehot_encoder_geo.categories_[0])
gender = st.selectbox('Gender', label_encoder_gender.classes_)
age = st.number_input('Age', min_value=18, max_value=100, value=30)
balance = st.number_input('Balance')
credit_score = st.number_input('Cresit Score')
estimated_salary = st.number_input('Estimated Salary')
tenure = st.slider('Tenure', 0, 10)
num_of_products = st.slider('Number Of Products', 1, 4)
has_cr_card = st.selectbox('Has Credit Card', [0, 1])
is_active_member = st.selectbox('Is Active Member', [0,1])

# Prepare the Input data
input_data = pd.DataFrame({
    'CreditScore': [credit_score],
    'Gender':[label_encoder_gender.transform([gender])[0]],
    'Age': [age],
    'Tenure':[tenure],
    'Balance': [balance],
    'NumOfProducts': [num_of_products],
    'HasCrCard': [has_cr_card],
    'IsActiveMember': [is_active_member],
    'EstimatedSalary': [estimated_salary]
})

# encode Geo
geo_encoder = onehot_encoder_geo.transform(
    [[geography]]).toarray()
geo_encoder_df = pd.DataFrame(geo_encoder,
                              columns=onehot_encoder_geo.get_feature_names_out(['Geography']))

#combine the data
input_data = pd.concat([input_data.reset_index(drop=True),
                           geo_encoder_df], axis=1)

# scaling the data
input_data_scaled = scaler.transform(input_data)

## Prediction churn

prediction = model.predict(input_data_scaled)

if prediction[0][0] > 0.5:
  st.write('The Customer is likely to churn.')
else:
  st.write('The Customer is not likely to churn.')
# Out:
# Overwriting app.py

# %%
# !streamlit run /content/app.py &>/content/logs.txt &

# %%
# !npx localtunnel --port 8000

# %%
# !streamlit run app.py &>/content/logs.txt & npx localtunnel --port 8501 & curl ipv4.icanhazip.com
# Out:
# 35.229.251.245
# ⠙your url is: https://hot-pugs-lie.loca.lt

# %%
# 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

# %%
# Replace with your details
token = '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'
user_name = 'apoorv280'
repo_name = 'GenAI_Projects'
code_folder = '/content/drive/MyDrive/genAI'

# %%
# Check Git version
# !git version

# %%
# Set up Git configuration
# !git config --global user.email "apoorvpandey6@gmail.com"
# !git config --global user.name "{apoorv280}"

# %%
# Clone GitHub repo
# !git clone https://{token}@github.com/{user_name}/{repo_name}.git
# Out:
# Cloning into 'GenAI_Projects'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 3 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (3/3), done.

# %%
# Sync Colab folder with GitHub repo
# !rsync -av "{code_folder}/" "/content/{repo_name}"
# Out:
# sending incremental file list
# app.ipynb
#
# sent 14,488 bytes  received 36 bytes  29,048.00 bytes/sec
# total size is 8,897,740  speedup is 612.62

# %%
# Push to GitHub
# %cd /content/{repo_name}
# !git add .
# !git commit -m "ANN Classification"
# !git remote add origin https://{token}@github.com/{user_name}/{repo_name}.git
# !git push -u origin colab
# Out:
# /content/GenAI_Projects
# [main 7f295aa] ANN Classification
#  1 file changed, 1 insertion(+), 1 deletion(-)
# error: remote origin already exists.
# error: src refspec colab-update does not match any
# error: failed to push some refs to 'https://github.com/apoorv280/GenAI_Projects.git'
